# %% [markdown]
# # <center> <font face = "Times New Roman" color = 'brown' size = '6'> <b> STUDENT'S T TEST </b> </font> </center>

# %% [markdown]
# ## <font face = "Times New Roman"> <b> Theoretical Overview </b> </font>

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Definition </b></font>

# %% [markdown]
# * The `T-test` i.e. `Student’s T Test` compares two **means** and tells us if they are different from each other.
# * It tells whether two samples have been drawn from same sample or not.
# * It tell's how significant our result is, more specifically it tells whether it happened by chance or not.

# %% [markdown]
# ### <font face = "Times New Roman"> <b> T-Values and Degrees of Freedom </b></font>

# %% [markdown]
# * `T-Value` is the ratio of the difference between the mean of the two sample sets and the variation that exists within the sample sets.
# * T-Value is also called `T-Score`.
# * Large t-score indicates that the groups are different.
# * Small t-score indicates that the groups are similar.
# * `Degree Of Freedom` are the values that has a freedom to vary.
# * **Formula of Degree of Freedom:** df = n<sub>x</sub> + n<sub>y</sub> - 2

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Normal Distribution </b></font>

# %% [markdown]
# * It has a `bell-shaped` density curve.
# * The density curve is symmetrical and centered about `mean(μ)`. It determines the **peak** of the curve.
# * Data spread it determined by `standard deviation(sigma-σ)` i.e. it is a measure of **variability**. It determines how far the data falls from the mean.
#
# The density curve is as follows: <sup>[1]</sup>

# %% [markdown]
# ![normalDistributionCurve.png](data:image/png;base64,...)

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Standardization (Normalization, z-Scores) </b></font>

# %% [markdown]
# * The process of putting different variables to a same scale is known as `Standardization`.
# * Also called `Normalization`.
# * It allows us to compare scores between different types of variables.
# * **Formula:**

# %% [markdown]
# ![z-score.png](data:image/png;base64,...)

# %% [markdown]
# * Result of this formula is known as `z-score`.
# * `z-score` tells the overall data lies compared to overall population.
#
# > <font color='green'><b> Note:</b></font> The higher (or lower) the Z-score, the more unlikely the result is to happen by chance and the more likely the result is meaningful.<sup>[1]</sup>

# %% [markdown]
# ### <font face = "Times New Roman"> <b> p-Value and alpha </b><font>

# %% [markdown]
# #### **Significance Level-Alpha**
#
# * It is a probability of rejecting the null hypothesis when it is true.
#
# * Drawing a two tailed graph for alpha = 0.05 and alpha = 0.01:<sup>[1]</sup>
#
# **Some Keypoints:**
# * We need to shade 5% or 1% of graph that is furthest from null hypothesis(since we are rejecting).
# * The sample mean for the given distribution is 330.6.

# %% [markdown]
# ![alpha0.05.png](data:image/png;base64,...)

# %% [markdown]
# ![alpha0.01.png](data:image/png;base64,...)

# %% [markdown]
# **Observation:**
#
# * For the above two-tailed test, the critical region (the shaded part) lies equidistant from the null hypothesis value.
# * Sample mean 330.6 is significant in case for 5% significance but not for the case of 1% significance level.
#
# **Conclusion**
#
# * We'll reject null hypothesis for 5% significance level.
# * Fail to reject null hypothesis for 1% significance level.

# %% [markdown]
# #### **P-Value**

# %% [markdown]
# * The probability that the results from our sample data occurred by chance is known as `p-value`.
# * Lower p-values are good because they indicate that the data does not occur by chance.
# * *Example:* p-value = 0.01 indicates that their is only 1% probability that the data occured by chance.
# * If the observed p-value is less than alpha, then the results are statistically significant.

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Type's Of T-Test </b></font>

# %% [markdown]
# #### **Student's T-Test**
#
# * Sample's are Independent.
# * Sample's are drawn from Gaussian Distribution.
# * Size of each sample must be same.
# * Sample's have same variance.
# * Sample's have different mean.
# * Values of one sample does not have any effect to values of other sample.
#
# **Formula:**<sup>[5]</sup>

# %% [markdown]
# ![ind_ttest.png](data:image/png;base64,...)

# %% [markdown]
# #### **Paired Student's T-Test**
#
# * Sample's are Dependent.
# * They may be from same population.
# * Used to check whether the difference of means of two samples are zero or not.
# * They have unequal variance.
# * Similar to Student's T-Test they are also drawn from Gaussian Distribution.
# * Values of one sample effect the values of other sample.
#
# **Formula:**

# %% [markdown]
# ![dep_ttest.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Hypothesis </b></font>
#
# * Hypothesis testing is used to assess the probability of a hypothesis by using sample data.
# * An assumption is made looking into population and test are preformed according to it.

# %% [markdown]
# #### **Null Hypothesis**
#
# * It stats/assumnes that their is no difference between population characteristics (mean, propotion).
# * It is denoted by H<sub>0</sub>.

# %% [markdown]
# #### **Alternative Hypothesis**
#
# * It claims that the population is contradictory to null hypothesis. Hence, reject null hypothesis.
# * It is denoted by H<sub>1</sub>.

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Procedure </b></font>

# %% [markdown]
# * Determine a null and alternate hypothesis.
# * Collect sample data.
# * Determine a confidence interval and degrees of freedom.
# * Calculate the t-statistic.
# * Calculate the critical t-value from the t distribution.
# * Compare the critical t-values with the calculated t statistic.

# %% [markdown]
# ## <font face = "Times New Roman"> <b> Using Library Functions </b> </font>

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Student's T-test (Independent Samples) </b></font>

# %% [markdown]
# #### **For n < 30 Sample Size**

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns

# %% [markdown]
# <font color = 'blue' size = '4'> <b> seed() </b> </font>
#
# * Initializes the pseudorandom number generator.
# * If we use the same seed to initialize, then the random output will remain same.
#
# > <font color = 'green' > <b> Note: </b> </font> Call it before generating random number.

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(1)

# %% [markdown]
# <font color = 'blue' size = '4'> <b> sci.stats.norm.rvs() </b></font>
#
# * Generates a normal continuous random variable.
# *  <font color='brown'> norm.rvs(): </font> This method is for random variates.
#
# **Parameters:**
#
# * <font color='brown'> size: </font> Number of random variates.
# *  <font color='brown'> loc: </font> Mean of the distribution.
# *  <font color='brown'> scale: </font> Standard deviation.

# %%
"""
    Genetating Independent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 12, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 12, loc = 40, scale = 4)

print("Sample1 Elements:", sample1)
print()
print("Sample2 Elements:", sample2)
# Out:
# Sample1 Elements: [50.49738145 41.55297435 41.88731299 39.70812551 47.46163052 34.79384521
#  50.97924706 40.9551724  45.27615638 43.0025185  49.84843175 35.75943716]
#
# Sample2 Elements: [38.71033118 38.46378258 44.53507777 35.60043493 39.31028717 36.48856633
#  40.16885499 42.33126085 35.59752329 44.57889484 43.60636288 42.00997736]

# %% [markdown]
# <font color = 'blue' size = '4'> <b> sns.distplot() </b> </font>
#
# * Combines the matplotlib `hist` function with the seaborn `kdeplot()` and `rugplot()` functions.
# * Fit `scipy.stats` distributions and plot the estimated *PDF* over the data.
#
# **Parameters:**
#
# * <font color='brown'> a: </font> Observed data.
# * <font color='brown'> bins: </font> Specification of hist bins.
# * <font color='brown'> kde: </font> Whether to plot a gaussian kernel density estimate. Type- Boolean.
# * <font color='brown'> color: </font> Color to plot everything but the fitted curve in.
# * <font color='brown'> hist_kws: </font> Keyword arguments for `matplotlib.axes.Axes.hist()`. Here, *alpha* significes the transparacy level.
#
# **Returns:**
#
# * <font color='brown'> ax: </font> Returns the Axes object with the plot.

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %% [markdown]
# <font color = 'blue' size = '4'> <b> ttest_ind() </b> </font>
#
# * Calculate the T-test for the means of two independent samples.
# * It is a two-sided test for the null hypothesis.
#
# > <font color = 'green'><b> Note: </b></font> Assumes that the populations have identical variances by default.
#
# **Parameters:**
#
# * <font color='brown'>a, b:</font> Array (must be of same dimentions)
# * <font color='brown'>axis:</font> Axis along which to compute test.
# * <font color='brown'>equal_var:</font> If True- Standard independent 2 sample test (assumes equal population variances). If False- Welch’s t-test (does not assume equal population variance)
# * <font color='brown'>nan_policy:</font> Defines how to handle when input contains nan.
# * <font color='brown'>alternative:</font> Defines the alternative hypothesis (two-sided, less: one-sided and greater: one-sided).
#
# **Returns:**
#
# * <font color='brown'> statistic: </font> The calculated t-statistic.
# * <font color='brown'> pvalue: </font> The two-tailed p-value.

# %%
"""
    Performing t-test using scipy library function.

"""

statistic, pvalue = sci.stats.ttest_ind(sample1, sample2)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Statistics:  1.8265324389355042
# P-Value:  0.08137168035605108

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %% [markdown]
# #### **For n > 30 Sample Size**

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(2)

# %%
"""
    Genetating Independent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 37, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 37, loc = 40, scale = 4)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Performing t-test using scipy library function.

"""

statistic, pvalue = sci.stats.ttest_ind(sample1, sample2)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Statistics:  3.6651141508256257
# P-Value:  0.0004695638522835156

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %% [markdown]
# #### **For n > 30 (Large Value) Sample Size**

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(3)

# %%
"""
    Genetating Independent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 113, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 113, loc = 40, scale = 4)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Performing t-test using scipy library function.

"""

statistic, pvalue = sci.stats.ttest_ind(sample1, sample2)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Statistics:  6.586317897782266
# P-Value:  3.1714061516473835e-10

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %% [markdown]
# #### **Conclusion**

# %% [markdown]
# * **p-val > alpha:** Null Hypothesis (H<sub>0</sub>) is accepted. Implies that they are from same distribution(same mean).
# * **p-val <= aplha:** Null Hypothesis (H<sub>0</sub>) is rejected. Implies that they are from different distribution (not same means).
# * Datas in bellow table represents the hypothesis accepted.
#
# <br>
# <table border='2'>
#     <tr>
#     <th> Alpha </th>
#     <th> n < 30 </th>
#     <th> n > 30 </th>
#     <th> n > 30(Large Val) </th>
#     </tr>
#     <tr>
#     <td> </td>
#     <td> p-val = 0.08 </td>
#     <td> p-val = 0.0004 </td>
#     <td> p-val = 3.1714061516473835e-10 </td>
#     <tr>
#     <td> 0.05 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.01 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.10 </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     </tr>
# </table>

# %% [markdown]
# ### <font face = "Times New Roman"> <b> Paired Student's T-Test (Dependent Samples) </b></font>

# %% [markdown]
# #### **For n < 30 Sample Size**

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(4)

# %%
"""
    Genetating Dependent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 12, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 12, loc = 44, scale = 7)

print("Sample1 Elements:", sample1)
print()
print("Sample2 Elements:", sample2)
# Out:
# Sample1 Elements: [44.20224683 45.99980533 40.01636428 46.77439403 42.32679392 37.66169106
#  41.40917293 46.3943007  45.32900013 39.41009347 46.47467876 43.64805229]
#
# Sample2 Elements: [46.97550678 46.32577202 35.90228617 46.45698007 39.75178902 54.8288553
#  49.06339126 44.32294897 37.11905843 44.38102917 45.11925055 35.53736289]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %% [markdown]
# <font color = 'blue' size = '4'> <b> ttest_rel() </b> </font>
#
# * Calculate the t-test on TWO RELATED samples.
# * Samples are expected to have identical average.
#
# **Parameters:**
#
# * <font color='brown'> a, b: </font> Two samples. They should have same size.
# * <font color='brown'> axis: </font> Axis along which to compute test.
# * <font color='brown'> nan_policy: </font> Defines how to handle when input contains nan.
# * <font color='brown'>alternative:</font> Defines the alternative hypothesis (two-sided, less: one-sided and greater: one-sided).
#
# **Returns:**
#
# * <font color='brown'> statistic: </font> The calculated t-statistic.
# * <font color='brown'> pvalue: </font> The two-tailed p-value.

# %%
"""
    Performing t-test using scipy library function.

"""

statistic, pvalue = sci.stats.ttest_rel(sample1, sample2)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Statistics:  -0.2515675549698785
# P-Value:  0.8060132725843583

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %% [markdown]
# #### **For n > 30 Sample Size**

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(5)

# %%
"""
    Genetating Dependent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 37, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 37, loc = 44, scale = 7)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Performing t-test using scipy library function.

"""

statistic, pvalue = sci.stats.ttest_rel(sample1, sample2)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Statistics:  -1.2602287439086148
# P-Value:  0.21569477848820814

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %% [markdown]
# #### **For n > 30 (Larger Value) Sample Size**

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(6)

# %%
"""
    Genetating Dependent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 113, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 113, loc = 44, scale = 7)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Performing t-test using scipy library function.

"""

statistic, pvalue = sci.stats.ttest_rel(sample1, sample2)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Statistics:  0.5731813753390218
# P-Value:  0.5676709430822716

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %% [markdown]
# #### **Conclusion**

# %% [markdown]
# * **p-val > alpha:** Null Hypothesis (H<sub>0</sub>) is accepted. Implies that they are from same distribution(same mean).
# * **p-val <= aplha:** Null Hypothesis (H<sub>0</sub>) is rejected. Implies that they are from different distribution (not same means).
# * Datas in bellow table represents the hypothesis accepted.
#
# <br>
# <table border='2'>
#     <tr>
#     <th> Alpha </th>
#     <th> n < 30 </th>
#     <th> n > 30 </th>
#     <th> n > 30(Large Val) </th>
#     </tr>
#     <tr>
#     <td> </td>
#     <td> p-val = 0.80 </td>
#     <td> p-val = 0.21 </td>
#     <td> p-val = 0.56 </td>
#     <tr>
#     <td> 0.05 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.01 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.10 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     </tr>
# </table>

# %% [markdown]
# ## <font face = "Times New Roman"> <b> Without Using Library Functions </b> </font>

# %% [markdown]
#  ### <font face = "Times New Roman"> <b> Student's T-Test (Independent Samples) </b> </font>

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns
import math

# %%
"""
    User defined function to calculate mean.

"""

def find_mean(sample, size):
  sum = 0
  for i in range(len(sample)):
    sum += sample[i]
  mean = float(sum/size)
  return mean

# %%
"""
    User defined function to calculate variance.

"""

def find_var(sample, size):
  vsum = 0
  mean = find_mean(sample, size)
  for i in range(0, size):
    vsum += (sample[i] - mean)**2
  var = float(vsum/(size-1))
  return var

# %%
"""
    User defined function to calculate standard deviation.

"""

def find_std(var1, var2):
  std = np.sqrt((var1 + var2)/2)
  return std

# %%
"""
    To calculate t-statistic.

"""

def ind_ttest(sample1, sample2, size):

  sample1_var = find_var(sample1, size)
  sample2_var = find_var(sample2, size)

  print("Variance of sample1:", sample1_var)
  print("Variance of sample2:", sample2_var)

  std_dev = find_std(sample1_var, sample2_var)

  print("Standard Deviation:", std_dev)

  sample1_mean = find_mean(sample1, size)
  sample2_mean = find_mean(sample2, size)

  t_stat = (sample1_mean - sample2_mean)/(std_dev * np.sqrt(2/size))

  return t_stat

# %% [markdown]
# <font color = 'blue' size = '4'> <b> sci.stats.t.cdf() </b></font>
#
# * It is a student’s t continuous random variable.
# * Here, `cdf` is for cumulative distribution function.
#
# **Parameters:**
#
# * <font color='brown'> x: </font> It is t-statistic.
# * <font color='brown'> df: </font> Degree of freedom.
# * <font color='brown'> loc: </font> Mean of Distribution.
# * <font color='brown'> scale: </font> Standard Deviation.

# %%
"""
    To calculate p-value, compare with critical t-value

"""

def ind_pval(sample1, sample2, size, t_statistic):
  # Degree of freedom.
  df = 2 * size - 2
  # p-value after comparision with the t-stat
  p = 1 - sci.stats.t.cdf(t_statistic, df = df)
  pval = 2 * p
  return pval

# %% [markdown]
# #### **For n < 30 Sample Size**

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(1)

# %%
"""
    Genetating Independent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 12, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 12, loc = 40, scale = 4)

print("Sample1 Elements:", sample1)
print()
print("Sample2 Elements:", sample2)
# Out:
# Sample1 Elements: [50.49738145 41.55297435 41.88731299 39.70812551 47.46163052 34.79384521
#  50.97924706 40.9551724  45.27615638 43.0025185  49.84843175 35.75943716]
#
# Sample2 Elements: [38.71033118 38.46378258 44.53507777 35.60043493 39.31028717 36.48856633
#  40.16885499 42.33126085 35.59752329 44.57889484 43.60636288 42.00997736]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Calculating t-statistics and pvalue by user defined function.

"""

size = 12
t_statistic = ind_ttest(sample1, sample2, size)
pvalue = ind_pval(sample1, sample2, size, t_statistic)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Variance of sample1: 29.750449798593873
# Variance of sample2: 10.858705823200836
# Standard Deviation: 4.506060120648343
# Statistics:  0.5731813753390218
# P-Value:  0.08137168035605002

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %% [markdown]
# #### **For n > 30 Sample Size**

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(2)

# %%
"""
    Genetating Independent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 37, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 37, loc = 40, scale = 4)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Calculating t-statistics and pvalue by user defined function.

"""

size = 37
t_statistic = ind_ttest(sample1, sample2, size)
pvalue = ind_pval(sample1, sample2, size, t_statistic)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Variance of sample1: 18.59866956474679
# Variance of sample2: 12.349374557349355
# Standard Deviation: 3.9337033519379765
# Statistics:  0.5731813753390218
# P-Value:  0.00046956385228336117

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %% [markdown]
# #### **For n > 30 (Larger Value) Sample Size**

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(3)

# %%
"""
    Genetating Independent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 113, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 113, loc = 40, scale = 4)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Calculating t-statistics and pvalue by user defined function.

"""

size = 113
t_statistic = ind_ttest(sample1, sample2, size)
pvalue = ind_pval(sample1, sample2, size, t_statistic)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Variance of sample1: 17.065692298709628
# Variance of sample2: 13.07236445600938
# Standard Deviation: 3.88188464245906
# Statistics:  0.5731813753390218
# P-Value:  3.1714053605469417e-10

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Different Distributions- Reject H0

# %% [markdown]
# #### **Conclusion**

# %% [markdown]
# * **p-val > alpha:** Null Hypothesis (H<sub>0</sub>) is accepted. Implies that they are from same distribution(same mean).
# * **p-val <= aplha:** Null Hypothesis (H<sub>0</sub>) is rejected. Implies that they are from different distribution (not same means).
# * Datas in bellow table represents the hypothesis accepted.
#
# <br>
# <table border='2'>
#     <tr>
#     <th> Alpha </th>
#     <th> n < 30 </th>
#     <th> n > 30 </th>
#     <th> n > 30(Large Val) </th>
#     </tr>
#     <tr>
#     <td> </td>
#     <td> p-val = 0.08 </td>
#     <td> p-val = 0.0004 </td>
#     <td> p-val = 3.1714061516473835e-10 </td>
#     <tr>
#     <td> 0.05 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.01 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.10 </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     <td> H<sub>1</sub> </td>
#     </tr>
# </table>

# %% [markdown]
#  ### <font face = "Times New Roman"> <b> Paired Student's T-Test (Dependent Samples) </b> </font>

# %%
"""
    Importing Required Libraries.
    
"""

import numpy as np
import scipy as sci
import seaborn as sns
import math

# %%
"""
    User defined function to calculate mean.

"""

def find_mean(sample, size):
  sum = 0
  for i in range(len(sample)):
    sum += sample[i]
  mean = float(sum/size)
  return mean

# %%
"""
    To find sum squared difference and sum difference between observations.

"""

def find_diff(sample1, sample2):
  sq_diff = sum([(sample1[i] - sample2[i]) ** 2 for i in range(len(sample1))])
  diff = sum([sample1[i] - sample2[i] for i in range(len(sample1))])
  return sq_diff, diff

# %%
"""
    To find standard deviation.

"""

def find_dev(sq_diff, diff, size):
  std = np.sqrt((sq_diff - (diff ** 2 / size)) / (size - 1))
  return std

# %%
"""
    To calculate t-statistic.

"""

def dep_ttest(sample1, sample2, size):

  sample1_mean = find_mean(sample1, size)
  sample2_mean = find_mean(sample2, size)

  print("Mean of Sample1:", sample1_mean)
  print("Mean of Sample2:", sample2_mean)

  sq_diff, diff = find_diff(sample1, sample2)
  std_dev = find_dev(sq_diff, diff, size)
  std_error = std_dev / np.sqrt(size)

  t_stat = (sample1_mean - sample2_mean) / std_error

  return t_stat

# %%
"""
    To calculate p-value, compare with critical t-value

"""

def dep_pval(sample1, sample2, size, t_statistic):
  # Degree of freedom.
  df = size - 1
  # p-value after comparision with the t-stat
  p = 1 - sci.stats.t.cdf(t_statistic, df = df)
  pval = 2 * p
  return pval

# %% [markdown]
# #### **For n < 30 Sample Size**

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(4)

# %%
"""
    Genetating Dependent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 12, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 12, loc = 44, scale = 7)

print("Sample1 Elements:", sample1)
print()
print("Sample2 Elements:", sample2)
# Out:
# Sample1 Elements: [44.20224683 45.99980533 40.01636428 46.77439403 42.32679392 37.66169106
#  41.40917293 46.3943007  45.32900013 39.41009347 46.47467876 43.64805229]
#
# Sample2 Elements: [46.97550678 46.32577202 35.90228617 46.45698007 39.75178902 54.8288553
#  49.06339126 44.32294897 37.11905843 44.38102917 45.11925055 35.53736289]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=12,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Calculating t-statistics and pvalue by user defined function.

"""

size = 12
t_statistic = ind_ttest(sample1, sample2, size)
pvalue = ind_pval(sample1, sample2, size, t_statistic)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Variance of sample1: 9.662910569554832
# Variance of sample2: 33.35259635229226
# Standard Deviation: 4.637645249576939
# Statistics:  0.5731813753390218
# P-Value:  1.2104338427540837

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %% [markdown]
# #### **For n > 30 Sample Size**

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(5)

# %%
"""
    Genetating Dependent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 37, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 37, loc = 44, scale = 7)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample2,
                  bins=37,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Calculating t-statistics and pvalue by user defined function.

"""

size = 37
t_statistic = ind_ttest(sample1, sample2, size)
pvalue = ind_pval(sample1, sample2, size, t_statistic)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Variance of sample1: 12.545106646849867
# Variance of sample2: 53.62816926090208
# Standard Deviation: 5.7520985695549385
# Statistics:  0.5731813753390218
# P-Value:  1.7815608374169631

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %% [markdown]
# #### **For n > 30 (Larger Value) Sample Size**

# %%
"""
    Seed Random Number Generator.

"""

np.random.seed(6)

# %%
"""
    Genetating Dependent Samples.

"""

sample1 = sci.stats.norm.rvs(size = 113, loc = 44, scale = 4)
sample2 = sci.stats.norm.rvs(size = 113, loc = 44, scale = 7)

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Plotting Normal Distribution

"""

ax = sns.distplot(sample1,
                  bins=113,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 10,'alpha':0.6})

ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
"""
    Calculating t-statistics and pvalue by user defined function.

"""

size = 113
t_statistic = ind_ttest(sample1, sample2, size)
pvalue = ind_pval(sample1, sample2, size, t_statistic)

print("Statistics: ", statistic)
print("P-Value: ", pvalue)
# Out:
# Variance of sample1: 15.617856835350812
# Variance of sample2: 47.40449887129011
# Standard Deviation: 5.613481794155964
# Statistics:  0.5731813753390218
# P-Value:  0.5683350195463392

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.05

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.01

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %%
"""
    Drawing Conclusion by using diffrent values of alpha.

"""

alpha = 0.10

print("Same Distributions- fails to Reject H0") if pvalue > alpha else print("Different Distributions- Reject H0")
# Out:
# Same Distributions- fails to Reject H0

# %% [markdown]
# #### **Conclusion**

# %% [markdown]
# * **p-val > alpha:** Null Hypothesis (H<sub>0</sub>) is accepted. Implies that they are from same distribution(same mean).
# * **p-val <= aplha:** Null Hypothesis (H<sub>0</sub>) is rejected. Implies that they are from different distribution (not same means).
# * Datas in bellow table represents the hypothesis accepted.
#
# <br>
# <table border='2'>
#     <tr>
#     <th> Alpha </th>
#     <th> n < 30 </th>
#     <th> n > 30 </th>
#     <th> n > 30(Large Val) </th>
#     </tr>
#     <tr>
#     <td> </td>
#     <td> p-val = 1.21 </td>
#     <td> p-val = 1.78 </td>
#     <td> p-val = 0.56 </td>
#     <tr>
#     <td> 0.05 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.01 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     </tr>
#     <tr>
#     <td> 0.10 </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     <td> H<sub>0</sub> </td>
#     </tr>
# </table>

# %% [markdown]
# ## <font face = "Times New Roman"> <b> Conclusion </b> </font>

# %% [markdown]
# * We are able to detect whether sample's are from same population or not.
# * Same random numbers are generated, when same seed() values are used.
# * Same results are obtained with and without using library functions.

# %% [markdown]
# ## <font face = "Times New Roman" color = 'blue'> <b> References </b></font>
#
# * Class Notes- SDA_2, SDA_3
# * https://machinelearningmastery.com/parametric-statistical-significance-tests-in-python/
# * https://machinelearningmastery.com/how-to-code-the-students-t-test-from-scratch-in-python/
# * https://docs.scipy.org/doc/scipy/reference/stats.html
# * https://towardsdatascience.com/inferential-statistics-series-t-test-using-numpy-2718f8f9bf2f
